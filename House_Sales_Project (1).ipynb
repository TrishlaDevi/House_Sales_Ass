# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('kc_house_data_NaN (1).csv')

# %%
df.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0       3.0       1.00
# 1           1  6414100192  20141209T000000  538000.0       3.0       2.25
# 2           2  5631500400  20150225T000000  180000.0       2.0       1.00
# 3           3  2487200875  20141209T000000  604000.0       4.0       3.00
# 4           4  1954400510  20150218T000000  510000.0       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0         int64
# id                 int64
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.describe()
# Out:
#         Unnamed: 0            id         price      bedrooms     bathrooms  \
# count  21613.00000  2.161300e+04  2.161300e+04  21600.000000  21603.000000
# mean   10806.00000  4.580302e+09  5.400881e+05      3.372870      2.115736
# std     6239.28002  2.876566e+09  3.671272e+05      0.926657      0.768996
# min        0.00000  1.000102e+06  7.500000e+04      1.000000      0.500000
# 25%     5403.00000  2.123049e+09  3.219500e+05      3.000000      1.750000
# 50%    10806.00000  3.904930e+09  4.500000e+05      3.000000      2.250000
# 75%    16209.00000  7.308900e+09  6.450000e+05      4.000000      2.500000
# max    21612.00000  9.900000e+09  7.700000e+06     33.000000      8.000000
#
#         sqft_living      sqft_lot        floors    waterfront          view  \
# count  21613.000000  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean    2079.899736  1.510697e+04      1.494309      0.007542      0.234303
# ...

# %%
df.drop(['id','Unnamed: 0','date','sqft_lot','waterfront','view','condition','grade','sqft_above','yr_renovated','zipcode','lat','long','sqft_living15','sqft_lot15'],axis=1,inplace=True)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  floors  sqft_basement  yr_built
# 0  221900.0       3.0       1.00         1180     1.0              0      1955
# 1  538000.0       3.0       2.25         2570     2.0            400      1951
# 2  180000.0       2.0       1.00          770     1.0              0      1933
# 3  604000.0       4.0       3.00         1960     1.0            910      1965
# 4  510000.0       3.0       2.00         1680     1.0              0      1987

# %%
df.isnull().sum()
# Out:
# price             0
# bedrooms         13
# bathrooms        10
# sqft_living       0
# floors            0
# sqft_basement     0
# yr_built          0
# dtype: int64

# %%
mean=df['bedrooms'].mean()
df['bedrooms'].replace(np.nan,mean, inplace=True)

# %%
mean1=df['bathrooms'].mean()
df['bathrooms'].replace(np.nan,mean, inplace=True)

# %%
df.isnull().sum()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# floors           0
# sqft_basement    0
# yr_built         0
# dtype: int64

# %%
gr=df.groupby('bedrooms')
j=gr.first()
j
# Out:
#               price  bathrooms  sqft_living  floors  sqft_basement  yr_built
# bedrooms
# 1.00000    350000.0    1.00000          700     1.0              0      1942
# 2.00000    180000.0    1.00000          770     1.0              0      1933
# 3.00000    221900.0    1.00000         1180     1.0              0      1955
# 3.37287   1095000.0    3.37287         3064     3.5              0      1990
# 4.00000    604000.0    3.00000         1960     1.0            910      1965
# 5.00000    530000.0    2.00000         1810     1.5              0      1900
# 6.00000    464000.0    3.00000         2300     2.0            700      1920
# 7.00000   1950000.0    3.50000         4640     2.0           1780      1965
# 8.00000    490000.0    5.00000         2800     2.0            920      1997
# 9.00000    599999.0    4.50000         3830     2.5           1380      1938
# 10.00000  1148000.0    5.25000         4590     1.0           2090      2008
# ...

# %%
j['price']
# Out:
# bedrooms
# 1.00000      350000.0
# 2.00000      180000.0
# 3.00000      221900.0
# 3.37287     1095000.0
# 4.00000      604000.0
# 5.00000      530000.0
# 6.00000      464000.0
# 7.00000     1950000.0
# 8.00000      490000.0
# 9.00000      599999.0
# 10.00000    1148000.0
# 11.00000     520000.0
# 33.00000     640000.0
# Name: price, dtype: float64

# %%
bed=df.bedrooms.value_counts()
bed
# Out:
# 3.00000     9824
# 4.00000     6882
# 2.00000     2760
# 5.00000     1601
# 6.00000      272
# 1.00000      199
# 7.00000       38
# 3.37287       13
# 8.00000       13
# 9.00000        6
# 10.00000       3
# 11.00000       1
# 33.00000       1
# Name: bedrooms, dtype: int64

# %% [markdown]
# # Price based on Bedrooms

# %%
sns.barplot(bed,j['price'])
# Out:
# /Users/trishladevi/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %% [markdown]
# # Price based on Bathrooms

# %%
gr1=df.groupby('bathrooms')
j1=gr1.first()
j1
# Out:
#                price  bedrooms  sqft_living  floors  sqft_basement  yr_built
# bathrooms
# 0.50000     273000.0   2.00000         1180     1.0            590      1945
# 0.75000     180250.0   2.00000          900     1.0              0      1941
# 1.00000     221900.0   3.00000         1180     1.0              0      1955
# 1.25000     397500.0   3.00000         1510     1.0            700      1961
# 1.50000     291850.0   3.00000         1060     1.0              0      1963
# 1.75000     400000.0   3.00000         1370     1.0              0      1977
# 2.00000     510000.0   3.00000         1680     1.0              0      1987
# 2.25000     538000.0   3.00000         2570     2.0            400      1951
# 2.50000     323000.0   3.00000         1890     2.0              0      2003
# 2.75000    2000000.0   3.00000         3050     1.0            720      1968
# 3.00000     604000.0   4.00000         1960     1.0            910      1965
# ...

# %%
bath=df['bathrooms'].value_counts()
bath
# Out:
# 2.50000    5380
# 1.00000    3852
# 1.75000    3048
# 2.25000    2047
# 2.00000    1930
# 1.50000    1446
# 2.75000    1185
# 3.00000     753
# 3.50000     731
# 3.25000     589
# 3.75000     155
# 4.00000     136
# 4.50000     100
# 4.25000      79
# 0.75000      72
# 4.75000      23
# 5.00000      21
# 5.25000      13
# 3.37287      10
# 5.50000      10
# 1.25000       9
# 6.00000       6
# 0.50000       4
# 5.75000       4
# 6.75000       2
# 8.00000       2
# 6.25000       2
# 6.50000       2
# 7.50000       1
# 7.75000       1
# Name: bathrooms, dtype: int64

# %%
plt.subplots(figsize=(15,10))
sns.barplot(bath,j1['price'])
# Out:
# /Users/trishladevi/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bathrooms', ylabel='price'>

# %% [markdown]
# # Price based on squarefeet living

# %%
sqrliv=df.groupby('sqft_living')
j2=sqrliv.first()
j2
# Out:
#                  price  bedrooms  bathrooms  floors  sqft_basement  yr_built
# sqft_living
# 290           142000.0   3.37287    3.37287     1.0              0      1963
# 370           276000.0   1.00000    0.75000     1.0              0      1923
# 380           245000.0   1.00000    0.75000     1.0              0      1963
# 384           265000.0   3.37287    0.75000     1.0              0      2003
# 390           228000.0   3.37287    1.00000     1.0              0      1953
# ...                ...       ...        ...     ...            ...       ...
# 9640         4668000.0   5.00000    6.75000     1.0           4820      1983
# 9890         6885000.0   6.00000    7.75000     2.0           1030      2001
# 10040        7062500.0   5.00000    4.50000     2.0           2360      1940
# 12050        7700000.0   6.00000    8.00000     2.5           3480      1910
# 13540        2280000.0   7.00000    8.00000     3.0           4130      1999
#
# [1038 rows x 6 columns]

# %%
sqrl=df['sqft_living'].value_counts()
sqrl
# Out:
# 1300    138
# 1400    135
# 1440    133
# 1800    129
# 1660    129
#        ...
# 9890      1
# 5584      1
# 1961      1
# 5720      1
# 1425      1
# Name: sqft_living, Length: 1038, dtype: int64

# %%
plt.subplots(figsize=(50,40))
sns.barplot(sqrl,j2['price'])
# Out:
# /Users/trishladevi/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %% [markdown]
# # Price based on the floors

# %%
floor=df.groupby('floors')
j3=floor.first()
j3
# Out:
#             price  bedrooms  bathrooms  sqft_living  sqft_basement  yr_built
# floors
# 1.0      221900.0   3.00000    1.00000         1180              0      1955
# 1.5      310000.0   3.00000    1.00000         1430              0      1927
# 2.0      538000.0   3.00000    2.25000         2570            400      1951
# 2.5     1385000.0   4.00000    3.25000         4860              0      1993
# 3.0      280000.0   2.00000    1.50000         1190              0      2005
# 3.5     1095000.0   3.37287    3.37287         3064              0      1990

# %%
flr=df['floors'].value_counts()
flr
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
plt.subplots(figsize=(10,5))
sns.barplot(flr,j3['price'])
# Out:
# /Users/trishladevi/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='floors', ylabel='price'>

# %% [markdown]
# # Price based on the square feet basement

# %%
sqrbas=df.groupby('sqft_basement')
j4=sqrbas.first()
j4
# Out:
#                    price  bedrooms  bathrooms  sqft_living  floors  yr_built
# sqft_basement
# 0               221900.0       3.0       1.00         1180     1.0      1955
# 10              163800.0       2.0       2.50         1000     2.0      2004
# 20              485000.0       2.0       2.50         1430     3.0      2008
# 40              277700.0       2.0       1.50         1240     2.0      1967
# 50              318888.0       4.0       1.75         2320     1.0      1973
# ...                  ...       ...        ...          ...     ...       ...
# 3260           1900000.0       5.0       4.25         6510     2.0      1980
# 3480           7700000.0       6.0       8.00        12050     2.5      1910
# 3500           3200000.0       4.0       3.25         7000     1.0      1991
# 4130           2280000.0       7.0       8.00        13540     3.0      1999
# 4820           4668000.0       5.0       6.75         9640     1.0      1983
#
# [306 rows x 6 columns]

# %%
base=df['sqft_basement'].value_counts()
base
# Out:
# 0      13126
# 600      221
# 700      218
# 500      214
# 800      206
#        ...
# 518        1
# 374        1
# 784        1
# 906        1
# 248        1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
plt.subplots(figsize=(50,40))
sns.barplot(base,j4['price'])
# Out:
# /Users/trishladevi/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sqft_basement', ylabel='price'>

# %% [markdown]
# # Price based on the year built

# %%
yrblt=df.groupby('yr_built')
j5=yrblt.first()
j5
# Out:
#              price  bedrooms  bathrooms  sqft_living  floors  sqft_basement
# yr_built
# 1900      530000.0       5.0       2.00         1810     1.5              0
# 1901      385000.0       3.0       1.00         1220     1.0              0
# 1902      650000.0       5.0       2.75         2550     1.5              0
# 1903      640000.0       3.0       2.50         2160     1.5            200
# 1904      640000.0       4.0       2.00         2360     2.0              0
# ...            ...       ...        ...          ...     ...            ...
# 2011      859900.0       4.0       2.75         3390     2.0              0
# 2012      355000.0       3.0       2.25         1860     2.0              0
# 2013      819900.0       5.0       2.75         3150     2.0              0
# 2014      861990.0       5.0       2.75         3595     2.0              0
# 2015      729500.0       3.0       2.50         1660     3.0            130
#
# [116 rows x 6 columns]

# %%
blt=df['yr_built'].value_counts()
blt
# Out:
# 2014    559
# 2006    454
# 2005    450
# 2004    433
# 2003    422
#        ...
# 1933     30
# 1901     29
# 1902     27
# 1935     24
# 1934     21
# Name: yr_built, Length: 116, dtype: int64

# %%
plt.subplots(figsize=(10,5))
sns.barplot(blt.head(10),j5['price'])
# Out:
# /Users/trishladevi/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='yr_built', ylabel='price'>
